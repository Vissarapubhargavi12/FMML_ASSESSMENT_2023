# %% [markdown]
# <a href="https://colab.research.google.com/github/Vissarapubhargavi12/FMML_ASSESSMENT_2023/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-29 12:30:14--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   229MB/s    in 0.3s
#
# 2024-03-29 12:30:17 (229 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 39961  1708.04672v1  3D reconstruction from a single image is a key...    cs
# 32947  1511.06435v3  Deep learning methods have resulted in signifi...    cs
# 23391   1201.3803v1  The use of hierarchical Conditional Random Fie...    cs
# 3333   1510.01722v1  We consider the task of building compact deep ...  stat
# 5239    1203.3533v1  Separation of the sources and analysis of thei...    cs
# ...             ...                                                ...   ...
# 12342  1712.00679v2  Generative Adversarial Networks (GAN) have bec...  stat
# 20995  1706.02794v1  Multi-Agent Path Finding (MAPF) is an NP-hard ...    cs
# 29997  1711.04433v4  The task of crowd counting is to automatically...    cs
# 3597   1802.02147v1  Estimating the travel time of a path is of gre...    cs
# 11185   1411.7924v1  We review a method for click-through rate pred...  stat
#
#                                                    title  year  \
# 39961  DeformNet: Free-Form Deformation Network for 3...  2017
# 32947  Comparative Study of Deep Learning Software Fr...  2015
# 23391  Image Labeling and Segmentation using Hierarch...  2012
# 3333   Structured Transforms for Small-Footprint Deep...  2015
# 5239   Source Separation and Higher-Order Causal Anal...  2012
# ...                                                  ...   ...
# 12342        GANGs: Generative Adversarial Network Games  2017
# 20995  Rapid Randomized Restarts for Multi-Agent Path...  2017
# 29997  Crowd counting via scale-adaptive convolutiona...  2017
# 3597   DeepTravel: a Neural Network Based Travel Time...  2018
# 11185  Predicting clicks in online display advertisin...  2014
#
#                                                 keywords
# 39961  [reconstruction, applications, manipulation, a...
# 32947  [significant, performance, improvements, appli...
# 23391  [hierarchical, conditional, selection, relabel...
# 3333   [pipelines, deployment, constrained, framework...
# 5239   [separation, connectivity, important, automati...
# ...                                                  ...
# 12342  [generative, adversarial, successful, framewor...
# 20995  [artificial, intelligence, applications, heuri...
# 29997  [automatically, pedestrian, perspective, appro...
# 3597   [estimating, importance, approaches, estimatin...
# 11185  [prediction, collaborative, filtering, factori...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 39961    [reconstruction, applications, manipulation, a...
# 32947    [significant, performance, improvements, appli...
# 23391    [hierarchical, conditional, selection, relabel...
# 3333     [pipelines, deployment, constrained, framework...
# 5239     [separation, connectivity, important, automati...
#                                ...
# 20876    [consistent, recollection, monitoring, configu...
# 15220    [reranking, reranking, transition, different, ...
# 12583    [performance, implementation, convolutional, i...
# 22862    [statistical, variables, restricted, boltzmann...
# 18726    [recognized, management, imprecision, vaguenes...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8911 words.
# Out of those 4567 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b7ff2242-df9b-4139-83bc-75ba950a3f54" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b7ff2242-df9b-4139-83bc-75ba950a3f54")) {                    Plotly.newPlot(                        "b7ff2242-df9b-4139-83bc-75ba950a3f54",                        [{"x":["reconstructions","information","computationally","expensive","generative","reconstruction","differentiable","benchmarks","manipulate","preserving","applications","manipulation","qualitatively","retrieval","quantitatively","augmented","significant","plausible","introduce","deformation","outperforms","extensible","experiments","connected","comparative","facilitate","utilization","framework","computation","performance","tensorflow","extensibility","frameworks","evaluating","corresponding","architecture","perspective","performed","application","developed","architectures","currently","competitive","algorithms","convolutional","improvements","implementation","important","deployment","segmentation","relabeling","conditional","selection","associated","hierarchical","continuum","explicitly","characterized","parameter","constrained","pipelines","effective","providing","evaluation","accelerate","compression","significantly","comparison","inference","statistical","tradeoffs","compactness","footprint","recognition","techniques","transforms","experimental","unstructured","displacement","configurations","structured","bottleneck","autoregressive","interesting","technique","uncorrelated","influences","identified","functions","discovered","causality","independent","exploiting","separation","resulting","separated","connectivity","conditionally","dependence","autocorrelations","variances","automatic","envelopes","multivariate","forecasting","generated","procesamiento","characteristics","parametric","reference","evaluated","predictions","robustness","estimation","classifier","knowledge","meaningful","represent","difficult","describes","restoring","activates","underlying","distribution","influence","specifically","classification","reconstructing","artificial","selecting","subsequently","subsampling","empirical","guarantee","demonstrate","hypothesis","utilizing","subsample","considers","proportional","practical","nonetheless","favorably","subsequent","composite","processing","inexactly","nonsmooth","minimizing","bioinformatics","convergence","desirable","directions","generalize","communities","attention","stochastic","structure","adjacency","identifying","overlapping","contribution","exploratory","automatically","blockmodel","recursive","eigenvalue","theoretically","biological","quantifiable","clustering","unlabeled","principal","determine","establish","community","probabilistic","algorithm","automated","detection","statistics","submissions","multiview","incorrect","discriminant","rewritten","forecasts","simulations","researchers","processes","quantitative","parameters","representation","identification","literature","extensive","neighboring","individuals","addressed","associating"],"y":[15,652,100,91,111,101,27,113,7,46,387,12,22,129,23,38,256,16,338,8,285,5,622,72,36,54,9,526,152,897,7,4,40,61,146,254,72,125,263,207,132,54,118,582,405,97,145,359,21,172,1,111,164,110,88,1,77,34,106,74,9,264,92,257,21,32,260,139,216,144,6,7,12,385,385,19,377,22,8,19,110,21,5,61,258,4,12,45,218,23,12,153,72,20,159,11,22,9,21,1,4,174,2,23,19,174,2,97,48,58,147,80,99,199,147,359,56,128,118,78,2,0,114,221,64,165,484,14,123,38,27,4,133,40,556,63,45,1,37,12,151,9,17,26,15,278,0,1,47,7,123,36,40,62,20,191,126,354,9,84,18,75,7,167,2,24,6,48,37,2,137,53,32,63,50,64,152,812,97,321,69,5,4,12,21,1,2,40,68,107,69,233,375,106,141,176,12,45,32,7],"type":"bar"},{"x":["reconstructions","information","computationally","expen ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4567,), (4567, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.78

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>A4NT</span> <span style=''>Author</span> <span style='background-color:rgba(0, 255, 0, 0.52);'>Attribute</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Anonymity</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Adversarial</span> <span style=''>Training</span> <span style=''>of</span> <span style=''>Neural</span> <span style=''>Machine</span> <span style='background-color:rgba(0, 255, 0, 0.834710743801653);'>Translation</span> <br/><br/><span style=''>Text</span> <span style=''>based</span> <span style=''>analysis</span> <span style=''>methods</span> <span style=''>allow</span> <span style=''>to</span> <span style=''>reveal</span> <span style=''>privacy</span> <span style=''>relevant</span> <span style=''>author</span> <span style='background-color:rgba(0, 255, 0, 0.40206185567010305);'>attributes</span> <span style=''>such</span> <span style=''>as</span> <span style=''>gender</span> <span style=''>age</span> <span style=''>and</span> <span style=''>identify</span> <span style=''>of</span> <span style=''>the</span> <span style=''>texts</span> <span style=''>author</span> <span style=''>Such</span> <span style=''>methods</span> <span style=''>can</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>compromise</span> <span style=''>the</span> <span style=''>privacy</span> <span style=''>of</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.7142857142857142);'>anonymous</span> <span style=''>author</span> <span style=''>even</span> <span style=''>when</span> <span style=''>the</span> <span style=''>author</span> <span style=''>tries</span> <span style=''>to</span> <span style=''>remove</span> <span style=''>privacy</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sensitive</span> <span style=''>content</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.5330396475770927);'>automatic</span> <span style=''>method</span> <span style=''>called</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Adversarial</span> <span style=''>Author</span> <span style='background-color:rgba(0, 255, 0, 0.52);'>Attribute</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Anonymity</span> <span style=''>Neural</span> <span style='background-color:rgba(0, 255, 0, 0.834710743801653);'>Translation</span> <span style=''>(A4NT)</span> <span style=''>to</span> <span style=''>combat</span> <span style=''>such</span> <span style=''>text</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>adversaries</span> <span style=''>We</span> <span style=''>combine</span> <span style=''>sequence</span> <span style=''>to</span> <span style=''>sequence</span> <span style=''>language</span> <span style=''>models</span> <span style=''>used</span> <span style=''>in</span> <span style=''>machine</span> <span style='background-color:rgba(0, 255, 0, 0.834710743801653);'>translation</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generative</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>adversarial</span> <span style=''>networks</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>obfuscate</span> <span style=''>author</span> <span style='background-color:rgba(0, 255, 0, 0.40206185567010305);'>attributes</span> <span style=''>Unlike</span> <span style=''>machine</span> <span style='background-color:rgba(0, 255, 0, 0.834710743801653);'>translation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>techniques</span> <span style=''>which</span> <span style=''>need</span> <span style=''>paired</span> <span style=''>data</span> <span style=''>our</span> <span style=''>method</span> <span style=''>can</span> <span style=''>be</span> <span style=''>trained</span> <span style= ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>On</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>overfitting</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>asymptotic</span> <span style=''>bias</span> <span style=''>in</span> <span style=''>batch</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reinforcement</span> <span style=''>learning</span> <span style=''>with</span> <span style=''>partial</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observability</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style=''>stands</span> <span style=''>in</span> <span style=''>the</span> <span style=''>context</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reinforcement</span> <span style=''>learning</span> <span style=''>with</span> <span style=''>partial</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observability</span> <span style=''>and</span> <span style=''>limited</span> <span style=''>data</span> <span style=''>In</span> <span style=''>this</span> <span style=''>setting</span> <span style=''>we</span> <span style=''>focus</span> <span style=''>on</span> <span style=''>the</span> <span style=''>tradeoff</span> <span style=''>between</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>asymptotic</span> <span style=''>bias</span> <span style=''>(suboptimality</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unlimited</span> <span style=''>data)</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>overfitting</span> <span style=''>(additional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>suboptimality</span> <span style=''>due</span> <span style=''>to</span> <span style=''>limited</span> <span style=''>data)</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretically</span> <span style=''>show</span> <span style=''>that</span> <span style=''>while</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>potentially</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>increasing</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>asymptotic</span> <span style=''>bias</span> <span style=''>a</span> <span style=''>smaller</span> <span style=''>state</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>decreases</span> <span style=''>the</span> <span style=''>risk</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>overfitting</span> <span style=''>Our</span> <span style=''>analysis</span> <span style=''>relies</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expressing</span> <span style=''>the</span> <span style=''>quality</span> <span style=''>of</span> <span style=''>a</span> <span style=''>state</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representation</span> <span style=''>by</span> <span style=''>bounding</span> <span style=''>L1</span> <span style=''>error</span> <span style=''>terms</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>associated</span> <span style=''>belief</span> <span style=''>states</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Theoretical</span> <span style=''>results</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>empirically</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>illustrated</span> <span style=''>when</span> <span style=''>the</span> <span style=''>state</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representation</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>truncated</span> <span style=''>history</span> <span style=''>of</span> <span style='b ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>On</span> <span style=''>Coreset</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333333);'>Constructions</span> <span style=''>for</span> <span style=''>the</span> <span style=''>Fuzzy</span> <span style=''>K</span> <span style=''>Means</span> <span style=''>Problem</span> <br/><br/><span style=''>The</span> <span style=''>fuzzy</span> <span style=''>K</span> <span style=''>means</span> <span style=''>problem</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generalization</span> <span style=''>of</span> <span style=''>the</span> <span style=''>K</span> <span style=''>means</span> <span style=''>problem</span> <span style=''>to</span> <span style=''>soft</span> <span style='background-color:rgba(255, 0, 0, 0.5555555555555556);'>clusterings</span> <span style=''>Although</span> <span style=''>popular</span> <span style=''>in</span> <span style=''>practice</span> <span style=''>the</span> <span style=''>first</span> <span style=''>(1epsilon)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>for</span> <span style=''>this</span> <span style=''>problem</span> <span style=''>have</span> <span style=''>been</span> <span style=''>proposed</span> <span style=''>only</span> <span style=''>recently</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>pursue</span> <span style=''>the</span> <span style=''>analysis</span> <span style=''>of</span> <span style=''>the</span> <span style=''>fuzzy</span> <span style=''>K</span> <span style=''>means</span> <span style=''>problem</span> <span style=''>further</span> <span style=''>by</span> <span style=''>making</span> <span style=''>use</span> <span style=''>of</span> <span style=''>coresets</span> <span style=''>A</span> <span style=''>coreset</span> <span style=''>is</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>representative</span> <span style=''>of</span> <span style=''>the</span> <span style=''>input</span> <span style=''>data</span> <span style=''>set</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>preserves</span> <span style=''>certain</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>properties</span> <span style=''>of</span> <span style=''>the</span> <span style=''>input</span> <span style=''>such</span> <span style=''>as</span> <span style=''>the</span> <span style=''>quality</span> <span style=''>of</span> <span style=''>a</span> <span style=''>solution</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>proof</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>technique</span> <span style=''>for</span> <span style=''>coresets</span> <span style=''>which</span> <span style=''>makes</span> <span style=''>use</span> <span style=''>of</span> <span style=''>the</span> <span style=''>notion</span> <span style=''>of</span> <span style=''>weak</span> <span style=''>coresets</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Following</span> <span style=''>this</span> <span style=''>approach</span> <span style=''>we</span> <span style=''>are</span> <span style=''>able</span> <span style=''>to</span> <span style=''>show</span> <span style=''>that</span> <span style=''>small</span> <span style=''>coresets</span> <span style=''>for</span> <span style=''>the</span> <span style=''>fuzzy</span> <span style=''>K</span> <span style=''>means</span> <span style=''>problem</span> <span style=''>exist</span> <span style=''>More</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>precisely</s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Real</span> <span style=''>Time</span> <span style=''>Adaptive</span> <span style=''>Image</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Compression</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>based</span> <span style=''>approach</span> <span style=''>to</span> <span style=''>lossy</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>compression</span> <span style=''>which</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>outperforms</span> <span style=''>all</span> <span style=''>existing</span> <span style=''>codecs</span> <span style=''>while</span> <span style=''>running</span> <span style=''>in</span> <span style=''>real</span> <span style=''>time</span> <span style=''>Our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>typically</span> <span style=''>produces</span> <span style=''>files</span> <span style=''>25</span> <span style=''>times</span> <span style=''>smaller</span> <span style=''>than</span> <span style=''>JPEG</span> <span style=''>and</span> <span style=''>JPEG</span> <span style=''>2000</span> <span style=''>2</span> <span style=''>times</span> <span style=''>smaller</span> <span style=''>than</span> <span style=''>WebP</span> <span style=''>and</span> <span style=''>17</span> <span style=''>times</span> <span style=''>smaller</span> <span style=''>than</span> <span style=''>BPG</span> <span style=''>on</span> <span style=''>datasets</span> <span style=''>of</span> <span style=''>generic</span> <span style=''>images</span> <span style=''>across</span> <span style=''>all</span> <span style=''>quality</span> <span style=''>levels</span> <span style=''>At</span> <span style=''>the</span> <span style=''>same</span> <span style=''>time</span> <span style=''>our</span> <span style=''>codec</span> <span style=''>is</span> <span style=''>designed</span> <span style=''>to</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>lightweight</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>deployable</span> <span style=''>for</span> <span style=''>example</span> <span style=''>it</span> <span style=''>can</span> <span style=''>encode</span> <span style=''>or</span> <span style=''>decode</span> <span style=''>the</span> <span style=''>Kodak</span> <span style=''>dataset</span> <span style=''>in</span> <span style=''>around</span> <span style=''>10ms</span> <span style=''>per</span> <span style=''>image</span> <span style=''>on</span> <span style=''>GPU</span> <span style=''>Our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>architecture</span> <span style=''>is</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>autoencoder</span> <span style=''>featuring</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>pyramidal</span> <span style=''>analysis</span> <span style=''>an</span> <span style=''>adaptive</span> <span style=''>coding</span> <span style=''>module</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularization</span> <span style=''>of</span> <span style=''>the</span> <span style=''>expected</span> <span style=''>codelength</span> <span style=''>We</span> <span style=''>also</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>supplement</span> <span style=''>our</span> <span style=''>approach</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>adversarial</span> <span style=''>training</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>specialized</span> <span style=''>towards</span> <span style=''>use</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>compression</span> ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	evaluation (0.09132906894100924)
# 	experimental (0.13397299218194741)
# 	representation (0.13326226012793177)
# 	knowledge (0.12757640369580667)
# 	architecture (0.09026297085998579)
# 	information (0.23169864960909736)
# 	detection (0.1140724946695096)
# 	different (0.2601279317697228)
# 	recognition (0.13681592039800994)
# 	convolutional (0.1439232409381663)
#
# Some Statistics words are:
# 	theoretical (0.14300100704934543)
# 	variables (0.14400805639476336)
# 	stochastic (0.14350453172205438)
# 	estimation (0.17270896273917422)
# 	distribution (0.18429003021148035)
# 	algorithm (0.3947633434038268)
# 	statistical (0.1646525679758308)
# 	dimensional (0.18328298086606243)
# 	inference (0.20040281973816718)
# 	regression (0.18126888217522658)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="6faeb4f5-af52-4e45-bbdb-fc7ebd2cc8dc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6faeb4f5-af52-4e45-bbdb-fc7ebd2cc8dc")) {                    Plotly.newPlot(                        "6faeb4f5-af52-4e45-bbdb-fc7ebd2cc8dc",                        [{"x":["reconstructions","information","computationally","expensive","generative","reconstruction","differentiable","benchmarks","manipulate","preserving","applications","manipulation","qualitatively","retrieval","quantitatively","augmented","significant","plausible","introduce","deformation","outperforms","extensible","experiments","connected","comparative","facilitate","utilization","framework","computation","performance","tensorflow","extensibility","frameworks","evaluating","corresponding","architecture","perspective","performed","application","developed","architectures","currently","competitive","algorithms","convolutional","improvements","implementation","important","deployment","segmentation","relabeling","conditional","selection","associated","hierarchical","continuum","explicitly","characterized","parameter","constrained","pipelines","effective","providing","evaluation","accelerate","compression","significantly","comparison","inference","statistical","tradeoffs","compactness","footprint","recognition","techniques","transforms","experimental","unstructured","displacement","configurations","structured","bottleneck","autoregressive","interesting","technique","uncorrelated","influences","identified","functions","discovered","causality","independent","exploiting","separation","resulting","separated","connectivity","conditionally","dependence","autocorrelations","variances","automatic","envelopes","multivariate","forecasting","generated","procesamiento","characteristics","parametric","reference","evaluated","predictions","robustness","estimation","classifier","knowledge","meaningful","represent","difficult","describes","restoring","activates","underlying","distribution","influence","specifically","classification","reconstructing","artificial","selecting","subsequently","subsampling","empirical","guarantee","demonstrate","hypothesis","utilizing","subsample","considers","proportional","practical","nonetheless","favorably","subsequent","composite","processing","inexactly","nonsmooth","minimizing","bioinformatics","convergence","desirable","directions","generalize","communities","attention","stochastic","structure","adjacency","identifying","overlapping","contribution","exploratory","automatically","blockmodel","recursive","eigenvalue","theoretically","biological","quantifiable","clustering","unlabeled","principal","determine","establish","community","probabilistic","algorithm","automated","detection","statistics","submissions","multiview","incorrect","discriminant","rewritten","forecasts","simulations","researchers","processes","quantitative","parameters","representation","identification","literature","extensive","neighboring","individuals","addressed","associating","unsupervised","exploited","scenarios","collected","additional","dictionary","transferring","extracted","neglecting","approaches","introducing","occlusions","management","probability","supervised","quadratic","objective","traditional","optimizes","demonstrating","assessing","attracted","inventory","quantities","considered","synthetic","prediction","suggested","impossible","approximate","regression","consisting","furthermore","different","derivations","componentwise","equations","nonlinear","components","criterion","characterizing","validation","dedicated","regularization","elaborated","derivation","according","increasing","conducted","deterministic","decreases","linguistic","collection","relationships","relations ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	activates
# 	inexactly
# 	functoriality
# 	kleinberg
# 	phenotyping
# 	gaussianity
# 	resembling
# 	representer
# 	dermatological
# 	statisticians
# 	encrypted
# 	unintentionally
# 	entrywise
# 	prohibits
# 	unperturbed
# 	rehabilitation
# 	undergoing
# 	therapies
# 	exposition
# 	transformative
# Some words which never appear in Statistics papers:
# 	utilization
# 	extensibility
# 	procesamiento
# 	associating
# 	occlusions
# 	componentwise
# 	elaborated
# 	adjectives
# 	prepositions
# 	enriching
# 	deformable
# 	fascinating
# 	efference
# 	obstacles
# 	volumetric
# 	deliberately
# 	journalism
# 	composable
# 	realizing
# 	accelerators

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0574494756474155e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7375
